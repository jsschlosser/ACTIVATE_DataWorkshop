# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.4.3-cp37-cp37m-manylinux1_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 4.8 MB/s eta 0:00:01
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 58.5 MB/s eta 0:00:01
# Requirement already satisfied: pyparsing>=2.2.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (2.4.7)
# Collecting pillow>=6.2.0
#   Downloading Pillow-8.3.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 57.3 MB/s eta 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (2.8.2)
# Collecting numpy>=1.16
#   Downloading numpy-1.21.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 67.2 MB/s eta 0:00:01
# Requirement already satisfied: six in /srv/conda/envs/notebook/lib/python3.7/site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# Installing collected packages: pillow, numpy, kiwisolver, cycler, matplotlib
# Successfully installed cycler-0.10.0 kiwisolver-1.3.2 matplotlib-3.4.3 numpy-1.21.2 pillow-8.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.3.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 4.7 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.17.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas) (1.21.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas) (2021.1)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Installing collected packages: pandas
# Successfully installed pandas-1.3.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib as plt 

# Load data file
df = pd.read_csv (r'ACTIVATE_20200229_data.csv')
print (df)
# Load data header file
df2 = pd.read_csv (r'ACTIVATE_20200229_column_labels.csv')
print (df2)
    
# x axis values 
x = df[:,1]
# corresponding y axis values 
y = df[:,4]
    
# plotting the points  
plt.plot(x, y/1000) 
    
# naming the x axis 
plt.xlabel('Time (UTC)') 
# naming the y axis 
plt.ylabel('Altitude (km)') 
    
# function to show the plot 
plt.show()
# Out:
#       2/29/2020 13:52  37.126208  -76.498849    31.082   147.9505    12.336  \
# 0     2/29/2020 13:52  37.121662  -76.507263   93.6960   332.3690  11.09800
# 1     2/29/2020 13:52  37.116539  -76.516419  163.7215   555.0930   9.64150
# 2     2/29/2020 13:52  37.110880  -76.526270  239.1160   807.5080   9.42750
# 3     2/29/2020 13:52  37.104368  -76.536196  345.1165  1224.6300  12.82450
# 4     2/29/2020 13:53  37.095390  -76.542894  532.5750  1860.6000  13.35900
# ...               ...        ...         ...       ...        ...       ...
# 1347  2/29/2020 17:36  37.145346  -76.460702   90.5005   327.2140   6.10650
# 1348  2/29/2020 17:37  37.142729  -76.465987   54.8745   210.5705   5.53600
# 1349  2/29/2020 17:37  37.140133  -76.471211   20.3885    95.6120   6.18400
# 1350  2/29/2020 17:37  37.137549  -76.476409   -8.7135   -15.8925   6.85900
# 1351  2/29/2020 17:37  37.135924  -76.479656  -22.8214   -62.7114   9.25429
#
#         -3.055  239.6745    89.949   3.0025  ...  NaN.144  NaN.145  NaN.146  \
# 0     -1.54950  238.2865   99.0460  2.30050  ...      NaN      NaN      NaN
# 1     -2.30150  237.7960  108.4920  1.50150  ...      NaN      NaN      NaN
# 2     -2.76300  237.4125  116.9270  0.69800  ...      NaN      NaN      NaN
# 3    -24.93450  226.9530  122.6000 -0.05400  ...  2075.02  2038.15  2560.73
# 4    -31.47350  202.9480  123.1430 -0.60700  ...  2075.02  2038.15  2560.73
# ...        ...       ...       ...      ...  ...      ...      ...      ...
# 1347  -0.06750  243.7420   63.1110  3.58150  ...  4206.65  3232.14  2365.77
# 1348  -1.17800  244.3410   60.7090  4.08850  ...  4206.65  3232.14  2365.77
# 1349  -1.09900  243.0960   60.1440  4.66500  ...  4206.65  3232.14  2365.77
# 1350  -0.95750  241.1250   58.1700  5.43300  ...  4206.65  3232.14  2365.77
# 1351   2.18286  241.0186   51.2143  6.18429  ...  4206.65  3232.14  2365.77
#
#       NaN.147  NaN.148  NaN.149  NaN.150  NaN.151  NaN.152  NaN.153
# 0         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3     1418.40  1639.62  1574.82  2522.44  2474.90  1858.55    1.108
# 4     1418.40  1639.62  1574.82  2522.44  2474.90  1858.55    1.108
# ...       ...      ...      ...      ...      ...      ...      ...
# 1347  2559.71  2651.61  2473.00  2368.84  2492.59  2387.76    1.021
# 1348  2559.71  2651.61  2473.00  2368.84  2492.59  2387.76    1.021
# 1349  2559.71  2651.61  2473.00  2368.84  2492.59  2387.76    1.021
# 1350  2559.71  2651.61  2473.00  2368.84  2492.59  2387.76    1.021
# 1351  2559.71  2651.61  2473.00  2368.84  2492.59  2387.76    1.021
#
# [1352 rows x 591 columns]
#                 Var1                     Var2                      Var3  \
# 0  midpoint_time_UTC  Latitude_THORNHILL_ deg  Longitude_THORNHILL_ deg
#
#                         Var4                             Var5  \
# 0  GPS_Altitude_THORNHILL_ m  Pressure_Altitude_THORNHILL_ ft
#
#                          Var6                       Var7  \
# 0  Pitch_THORNHILL_ deg +-180  Roll_THORNHILL_ deg +-180
#
#                                 Var8                           Var9  \
# 0  True_Heading_THORNHILL_ deg 0-360  True_Air_Speed_THORNHILL_ m/s
#
#                                         Var10  ...                    Var582  \
# 0  Static_Air_Temp_THORNHILL_ degrees Celcius  ...  SMPS_Bin22_ZIEMBA_ #/cm3
#
#                      Var583                    Var584  \
# 0  SMPS_Bin23_ZIEMBA_ #/cm3  SMPS_Bin24_ZIEMBA_ #/cm3
#
#                      Var585                    Var586  \
# 0  SMPS_Bin25_ZIEMBA_ #/cm3  SMPS_Bin26_ZIEMBA_ #/cm3
#
#                      Var587                    Var588  \
# 0  SMPS_Bin27_ZIEMBA_ #/cm3  SMPS_Bin28_ZIEMBA_ #/cm3
#
#                      Var589                    Var590  \
# 0  SMPS_Bin29_ZIEMBA_ #/cm3  SMPS_Bin30_ZIEMBA_ #/cm3
#
#                       Var591
# 0  stdPT_ZIEMBA_$3_ unitless
#
# [1 rows x 591 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_96/3656180014.py in <module>
#      10
#      11 # x axis values
# ---> 12 x = df[:,1]
#      13 # corresponding y axis values
#      14 y = df[:,4]
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3359             casted_key = self._maybe_cast_indexer(key)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#    3363                 raise KeyError(key) from err
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
#